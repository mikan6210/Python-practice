# %% [markdown]
# <a href="https://colab.research.google.com/github/mikan6210/Python-practice/blob/main/%E4%BD%93%E6%B8%A9%E3%83%81%E3%82%A7%E3%83%83%E3%82%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#体温チェック
body_temperature=float(input('体温を入力してください>>'))
if body_temperature>=37.5:
  print('発熱があります，お家でゆっくり休んでください') #ユーザーが間違って整数で入力してしまった時はどうする？
else:
  print('問題ありません')
