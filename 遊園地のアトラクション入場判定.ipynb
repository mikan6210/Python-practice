# %% [markdown]
# <a href="https://colab.research.google.com/github/mikan6210/Python-practice/blob/main/%E9%81%8A%E5%9C%92%E5%9C%B0%E3%81%AE%E3%82%A2%E3%83%88%E3%83%A9%E3%82%AF%E3%82%B7%E3%83%A7%E3%83%B3%E5%85%A5%E5%A0%B4%E5%88%A4%E5%AE%9A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#遊園地のアトラクション入場判定
height=int(input('あなたの身長(cm)を入力して下さい>>'))
if height>=120:
  print('乗車可能です，楽しんできてください。')
else:
  print('申し訳ありません，このアトラクションは120cm以上の方のみご乗車いただけます。')
